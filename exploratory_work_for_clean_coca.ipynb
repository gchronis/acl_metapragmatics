# %% [markdown]
# COCA corpus has a special feature that removes ten tokens every 200 tokens and replaces them with an @ symbol.
#
# So we want to pass through the corpus and remove those sentences.
#
# We have a copy of the corpus stored in `/Volumes/data_gabriella_chronis/corpora/COCA`

# %%
#from __future__ import print_function
#import time
import numpy as np
import pandas as pd
import os

#from sklearn.decomposition import PCA
#from sklearn.manifold import TSNE
import pyarrow
import fastparquet

import csv
import re

import spacy
from collections import defaultdict 
from tqdm import tqdm

from spacy.matcher import PhraseMatcher, Matcher

_COCA_PATH = "/Volumes/data_gabriella_chronis/corpora/COCA/"
_COCA_METADATA = "/Volumes/data_gabriella_chronis/corpora/COCA/shared_files/coca-sources.txt"

_OUT_DIR = '/Volumes/data_gabriella_chronis/corpora/coca.2017.parquet'

# %% [markdown]
# First, let's explore the data by reading in one of the files

# %%
path = "texts/text_fiction_awq/w_fic_2012.txt"
example_text = open(_COCA_PATH+path, "r")

# %%
example_text.readline()
# Out:
# '\n'

# %% [markdown]
# Our goal is to take this corpus and to turn it into a giant data frame and to store that data   frame in a parquet file.
#
# I want the data frame to have the following format/columns
#
#
# | doc_id | doc_text | year | genre |

# %% [markdown]
# 1. for each file
# 2. split the file on the doc id
# 3. keep the doc id
# 4. sentencize the doc with spacy
# 5. remove the sentences that have the @@@@@ symbols
# 6. (don't actually do this yet---add the genre)
# 7. put into a dataframe
# 8. write/append to a parquet file.

# %% [markdown]
# We have metadata in COCA/shared_files/coca-sources.txt

# %%
columns = ["textID", "#words", "year", "genre", "subgen", "source", "title", "publication_info"]
#dtype = {"textID": int, "#words": int, "year": int, "subgen": int }
metadata = pd.read_csv( _COCA_METADATA, skiprows=3, sep='\t', names = columns, encoding='unicode_escape')
#metadata = metadata.convert_dtypes(infer_objects=False)
#metadata["textID"] = metadata["textID"].astype(np.int64, errors = 'ignore')

""""
we need nice pkey values
""""

# Convert the column to numeric, invalid parsing will be set as NaN
metadata['textID'] = pd.to_numeric(metadata['textID'], errors='coerce')

# Drop rows where 'textID' is NaN
metadata = metadata.dropna(subset=['textID'])

# Convert 'textID' back to integer type if desired
metadata['textID'] = metadata['textID'].astype(np.int64)
# Out:
# /var/folders/9m/vzvx58rs51v_x5nm620fz4xr0000gn/T/ipykernel_1539/3269366552.py:3: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv( _COCA_METADATA, skiprows=3, sep='\t', names = columns, encoding='unicode_escape')

# %%
metadata.head(5)
# Out:
#    textID  #words    year genre  subgen    source  \
# 0  221118  8101.0  1990.0  SPOK   200.0  ABC_2020
# 1  221119  8358.0  1990.0  SPOK   200.0  ABC_2020
# 2  221120  7824.0  1990.0  SPOK   200.0  ABC_2020
# 3  221121  8559.0  1990.0  SPOK   200.0  ABC_2020
# 4  221122  8199.0  1990.0  SPOK   200.0  ABC_2020
#
#                                                title publication_info
# 0  Is He a Killer?; Who Will Love My Pet?; The Tw...               --
# 1  Golden Years Behind Bars; The Joker; Goodbye W...               --
# 2  Too Old Too Soon; Danger on the Half Shell; Mi...               --
# 3  Chicken at Any Price?; The Daytop Solution; Su...               --
# 4  Children of Terror; Against All Odds; Buck Fev...               --

# %%
 #pecify the path to your text file
#input_file_path = 'path/to/your/file.txt'

# Read the entire content of the text file into a string
with open(_COCA_PATH+path, 'r') as file:
    text = file.read()

# Define the regular expression pattern to match the delimiters
pattern = r'\n##\d{7}'

# Find all matches of the pattern
matches = list(re.finditer(pattern, text))

# create a list of match texts, which are our document ids
doc_ids = [match.group()[3:] for match in matches] # get rid of the initial special characters on str_id
print(len(doc_ids))

# Initialize a list to store the captured segments, which are our document texts
doc_texts = []

# Add the text between matches
start_idx = 0
for match in matches:
    end_idx = match.start()
    if end_idx > start_idx:
        doc_texts.append(text[start_idx:end_idx].strip())
    start_idx = match.end()

# Add the text after the last match
if start_idx < len(text):
    doc_texts.append(text[start_idx:].strip())

# Create a DataFrame from the captured segments
df = pd.DataFrame(data = {'textID': doc_ids, 'doc_text': doc_texts})

"""
we need nice pkey values for our join
"""

# Convert the column to numeric, invalid parsing will be set as NaN
df['textID'] = pd.to_numeric(df['textID'], errors='coerce')

# Drop rows where 'textID' is NaN
df = df.dropna(subset=['textID'])

# Convert 'textID' back to integer type if desired
df['textID'] = df['textID'].astype(np.int64)
# Out:
# 508

# %%
df
# Out:
#       textID                                           doc_text
# 0    4120102  " The only problem with leaving four car lengt...
# 1    4120103  Waiting for spring in Reno , Nevada , is like ...
# 2    4120106  One hour down . Three hours to go . <p> The af...
# 3    4120107  After dinner with the first couple , Ida , Mav...
# 4    4120108  The letter , contemplated and worried about fo...
# ..       ...                                                ...
# 503  4122123  The milky dhatura gum would siphon out my soul...
# 504  4122124  A flux of vertical wind pushed Guido Tarkenen ...
# 505  4122125  I was eleven , the age when I knew everything ...
# 506  4122126  Margo was sitting on one of the wooden benches...
# 507  4122127  This is not a story . The people I mention her...
#
# [508 rows x 2 columns]

# %% [markdown]
# Now we want to remove the sentences from each doc that have @@@@@@s in them. Lets grab an example doc

# %%
nlp = spacy.load("en_core_web_sm", disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer", "ner"])
nlp.add_pipe('sentencizer')

# %%
df.iloc[0].doc_text[:1000]
# Out:
# '" The only problem with leaving four car lengths in front of you is that four cars come in to fill up the space ! " Hannah Swensen complained to her sister Michelle , who was riding in the passenger seat of her cookie truck . " I \'m going forty . Do you think that \'s too slow ? " <p> " Absolutely not . It \'s nasty out there , and anybody who drives faster than forty on a night like this is crazy . " <p> " Or they come from other states and they do n\'t know anything about winter driving in Minnesota . I think I \'ll pull over as far as I can and let that whole herd of cars behind me pass . " <p> " Good idea . " <p> Hannah signaled and moved over as far as she could to encourage the other drivers to pass her . They probably thought she was being too cautious , but a thin film of water glistened on the asphalt surface of the highway , and the temperature was dropping fast . @ @ @ @ @ @ @ @ @ @ of minutes and there was no way Hannah wanted to sail off into the ditch and land in the mud that'

# %%
def strip_censored_sents(text):
    censor_string = "@ @ @ @ @ @ @ @ @ @"
    # Process the text with spaCy
    doc = nlp(text)
    
    # Initialize a list to store sentences containing the specific string
    filtered_sentences = []
    
    # Iterate over the sentences in the document
# %%
df.head(5)
# Out:
#     doc_id                                           doc_text
# 0  4120102  " The only problem with leaving four car lengt...
# 1  4120103  Waiting for spring in Reno , Nevada , is like ...
# 2  4120106  One hour down . Three hours to go . <p> The af...
# 3  4120107  After dinner with the first couple , Ida , Mav...
# 4  4120108  The letter , contemplated and worried about fo...

# %%
metadata.head(5)
# Out:
#    textID  #words  year genre  subgen    source  \
# 0  221118  8101.0  1990  SPOK     200  ABC_2020
# 1  221119  8358.0  1990  SPOK     200  ABC_2020
# 2  221120  7824.0  1990  SPOK     200  ABC_2020
# 3  221121  8559.0  1990  SPOK     200  ABC_2020
# 4  221122  8199.0  1990  SPOK     200  ABC_2020
#
#                                                title publication_info
# 0  Is He a Killer?; Who Will Love My Pet?; The Tw...               --
# 1  Golden Years Behind Bars; The Joker; Goodbye W...               --
# 2  Too Old Too Soon; Danger on the Half Shell; Mi...               --
# 3  Chicken at Any Price?; The Daytop Solution; Su...               --
# 4  Children of Terror; Against All Odds; Buck Fev...               --

# %%
merged_df = pd.merge(df, metadata, on='textID', how='left')

# %%
merged_df
# Out:
#       textID                                           doc_text   #words  \
# 0    4120102  " The only problem with leaving four car lengt...   3009.0
# 1    4120103  Waiting for spring in Reno , Nevada , is like ...   2538.0
# 2    4120106  One hour down . Three hours to go . <p> The af...   1657.0
# 3    4120107  After dinner with the first couple , Ida , Mav...   2964.0
# 4    4120108  The letter , contemplated and worried about fo...    605.0
# ..       ...                                                ...      ...
# 503  4122123  The milky dhatura gum would siphon out my soul...   3126.0
# 504  4122124  A flux of vertical wind pushed Guido Tarkenen ...   5029.0
# 505  4122125  I was eleven , the age when I knew everything ...   4211.0
# 506  4122126  Margo was sitting on one of the wooden benches...   4510.0
# 507  4122127  This is not a story . The people I mention her...  14384.0
#
#        year genre  subgen                             source  \
# 0    2012.0   FIC   222.0               Cinnamon Roll murder
# 1    2012.0   FIC   222.0          Murder unleashed :a novel
# 2    2012.0   FIC   222.0                     Oath of office
# 3    2012.0   FIC   222.0                           Deadline
# 4    2012.0   FIC   222.0  Letter from a stranger :[a novel]
# ..      ...   ...     ...                                ...
# 503  2012.0   FIC   222.0                     India Currents
# 504  2012.0   FIC   222.0                 The Antioch Review
# 505  2012.0   FIC   222.0                 The Antioch Review
# 506  2012.0   FIC   222.0                 The Antioch Review
# 507  2012.0   FIC   222.0                 The Antioch Review
#
#                                  title  \
# 0                 Cinnamon Roll murder
# 1            Murder unleashed :a novel
# 2                       Oath of office
# 3                             Deadline
# 4    Letter from a stranger :[a novel]
# ..                                 ...
# 503                            Dhatura
# 504              Guido's Tale: The Job
# 505                             Eleven
# 506                   Bringing Up Baby
# 507               In the Sparrow Hills
#
#                                    publication_info
# 0                      New York : Kensington Books,
# 1      New York : Ballantine Books,Edition: 1st ed.
# 2    New York : St. Martin's Press,Edition: 1st ed.
# 3           New York : Kensington Publishing Corp.,
# 4    New York : St. Martin's Press,Edition: 1st ed.
# ..                                              ...
# 503                                        Mar 2012
# 504                                     Spring 2012
# 505                                     Spring 2012
# 506                                     Spring 2012
# 507                                     Spring 2012
#
# [508 rows x 9 columns]

# %%
metadata.dtypes
# Out:
# textID                int64
# #words               object
# year                float64
# genre                object
# subgen              float64
# source               object
# title                object
# publication_info     object
# dtype: object

# %%
df.dtypes
# Out:
# textID       int64
# doc_text    object
# dtype: object

# %%
metadata[metadata.textID ==4122123]
# Out:
#         textID  #words    year genre  subgen          source    title  \
# 60423  4122123  3126.0  2012.0   FIC   222.0  India Currents  Dhatura
#
#       publication_info
# 60423         Mar 2012

# %% [markdown]
# We want to do all of the above for every text file in the coca corpus

# %%
def get_text_file_names():
    # Define the root directory
    root_dir = _COCA_PATH + "texts"
    
    # List to store paths of all text files
    text_files = []
    
    # Walk through the directory
    for root, dirs, files in os.walk(root_dir):
        for dir_name in dirs:
            sub_dir_path = os.path.join(root, dir_name)
            # Find all text files in the current subdirectory
            for txt_file in os.listdir(sub_dir_path):
                text_files.append(os.path.join(sub_dir_path, txt_file))
    return text_files

# %%
get_text_file_names()
# Out:
# ['/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2016_acad.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2016_fic.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2016_mag.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2016_news.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2016_spok.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2017_acad.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2017_fic.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2017_mag.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2017_news.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/coca2017_text_qpj/2017_spok.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2012_acad.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2012_fic.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2012_mag.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2012_news.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2012_spok.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2013_acad.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2013_fic.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2013_mag.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2013_news.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2013_spok.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2014_acad.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2014_fic.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2014_mag.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2014_news.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2014_spok.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2015_acad.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2015_fic.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2015_mag.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2015_news.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_2012-2015_ksr/2015_spok.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1990.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1991.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1992.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1993.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1994.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1995.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1996.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1997.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1998.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_1999.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2000.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2001.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2002.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2003.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2004.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2005.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2006.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2007.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2008.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2009.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2010.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2011.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_academic_rpe/w_acad_2012.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1990.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1991.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1992.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1993.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1994.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1995.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1996.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1997.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1998.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_1999.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2000.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2001.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2002.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2003.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2004.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2005.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2006.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2007.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2008.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2009.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2010.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2011.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_fiction_awq/w_fic_2012.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1990.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1991.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1992.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1993.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1994.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1995.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1996.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1997.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1998.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_1999.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2000.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2001.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2002.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2003.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2004.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2005.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2006.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2007.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2008.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2009.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2010.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2011.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_magazine_jag/w_mag_2012.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1990.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1991.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1992.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1993.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1994.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1995.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1996.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1997.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1998.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_1999.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2000.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2001.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2002.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2003.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2004.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2005.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2006.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2007.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2008.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2009.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2010.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2011.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_newspaper_lsp/w_news_2012.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1990.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1991.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1992.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1993.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1994.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1995.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1996.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1997.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1998.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_1999.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2000.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2001.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2002.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2003.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2004.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2005.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2006.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2007.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2008.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2009.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2010.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2011.txt',
#  '/Volumes/data_gabriella_chronis/corpora/COCA/texts/text_spoken_kde/w_spok_2012.txt']
